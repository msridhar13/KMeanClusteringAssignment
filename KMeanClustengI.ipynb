# %%
#import all libraries
import numpy as np
from sklearn import cluster, datasets
from scipy import misc
from skimage import io

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Step 1: Loading the image
f = misc.face(gray=True)
face = io.imread('face.png')
plt.imshow(f)

# %% [markdown]
# ## Basic Information about the Image(Data)

# %%
#Creating a numpy array from an image file:
X=face.shape

# %%
face.dtype
# Out:
# dtype('uint8')

# %%
#face=face.reshape(face.shape[0]*face.shape[1],3)

face_r = (face / 255.0).reshape(-1,3) 
#print(face)
#Run the Kmeans algorithm
from sklearn.cluster import KMeans
km = KMeans(n_clusters=5)
km.fit(face_r)
# Out:
# KMeans(copy_x=True, init='k-means++', max_iter=300, n_clusters=5, n_init=10,
#     n_jobs=1, precompute_distances='auto', random_state=None, tol=0.0001,
#     verbose=0)

# %%
km.labels_
# Out:
# array([2, 4, 4, ..., 4, 4, 4])

# %%
km.labels_.shape
# Out:
# (262144,)

# %%
## Create the new image with the Cluster=5 and lables
newimg = km.cluster_centers_[km.labels_]

# %%
newimg.shape
# Out:
# (262144, 3)

# %% [markdown]
# ## Reshape the New Image Array with Original Image Dimensions

# %%
newimg=np.reshape(newimg, (image.shape))

# %% [markdown]
# ## Check the basic information of the newimage data

# %%
newimg.shape
# Out:
# (768, 1024)

# %%
newimg.dtype
# Out:
# dtype('float64')

# %%
###Plot the compressed image
fig = plt.figure(figsize=(8,8))
ax=fig.add_subplot(1,2,1,xticks=[],yticks=[],title='Acutal\Original Image')
ax.imshow(f)
ax=fig.add_subplot(1,2,2,xticks=[],yticks=[],title='Color Compressed Image using K-Means=5')
ax.imshow(newimg)
plt.show()
